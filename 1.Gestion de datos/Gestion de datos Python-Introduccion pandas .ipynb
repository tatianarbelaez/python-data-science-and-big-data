# %%
df = pd.read_csv(r"C:\Users\user\Downloads\2019Med2000_flatfiles\vwPlanBenefitsDetails.csv", nrows = 1000000)

# %%
df.head()
#Las primeras filas de la base
df.tail()
#ultimas filas de la base
# Out:
#   Contract_ID  Plan_ID  Segment_ID  Contract_Year Language_Name  \
# 0       H0001        1           0           2019       English
# 1       H0001        1           0           2019       Spanish
# 2       H0001        1           0           2019       English
# 3       H0001        1           0           2019       Spanish
# 4       H0001        1           0           2019       English
#
#                                        Category_Name  Category_Sort  \
# 0                             Health plan deductible              1
# 1                  Deducibles de los planes de salud              1
# 2                     Other health plan deductibles?              2
# 3               �Otros Deducibles del plan de salud?              2
# 4  Maximum out-of-pocket enrollee responsibility ...              3
#
#   Service_Name  Limit_Flag  Authorization_Flag  Referral Flag  Service_Sort  \
# 0          NaN         NaN                 NaN            NaN             0
# ...

# %%
df.sample(frac = 1)
#datos desordenados, pero la base no queda guardada
# Out:
#        Contract_ID  Plan_ID  Segment_ID  Contract_Year Language_Name  \
# 208636       H2450        2           0           2019       English
# 344426       H3954      156          11           2019       English
# 110502       H1350       15           1           2019       English
# 143959       H1666        2           0           2019       English
# 74683        H1016      803           0           2019       Spanish
# ...            ...      ...         ...            ...           ...
# 635960       H8432      810           0           2019       English
# 152747       H1951       47           1           2019       Spanish
# 666184       H9403        1           0           2019       English
# 641282       H8597        2           0           2019       English
# 461910       H5253      802           0           2019       English
#
#                             Category_Name  Category_Sort  \
# 208636                      Doctor visits              8
# ...

# %%
df.columns
# Todas las columnas de la base
# Out:
# Index(['Contract_ID', 'Plan_ID', 'Segment_ID', 'Contract_Year',
#        'Language_Name', 'Category_Name', 'Category_Sort', 'Service_Name',
#        'Limit_Flag', 'Authorization_Flag', 'Referral Flag', 'Service_Sort',
#        'Network_Description', 'Cost_Share', 'Network_Sort'],
#       dtype='object')

# %%
df.Language_Name
#Busca los datos en la columna
# Out:
# 0         English
# 1         Spanish
# 2         English
# 3         Spanish
# 4         English
#            ...
# 706241    English
# 706242    Spanish
# 706243    Spanish
# 706244    Spanish
# 706245    Spanish
# Name: Language_Name, Length: 706246, dtype: object

# %%
df.dtypes
#Tipo de datos de cada columna
# Out:
# Contract_ID             object
# Plan_ID                  int64
# Segment_ID               int64
# Contract_Year            int64
# Language_Name           object
# Category_Name           object
# Category_Sort            int64
# Service_Name            object
# Limit_Flag             float64
# Authorization_Flag     float64
# Referral Flag          float64
# Service_Sort             int64
# Network_Description     object
# Cost_Share              object
# Network_Sort             int64
# dtype: object

# %%
df.values 
#Arreglo con todos los datos, permite hacer operaciones matriciales
# Out:
# array([['H0001', 1, 0, ..., nan, '$185', 5],
#        ['H0001', 1, 0, ..., nan, '$185', 5],
#        ['H0001', 1, 0, ..., nan, 'Yes', 5],
#        ...,
#        ['R7444', 13, 0, ..., 'Fuera de la red', '40%', 19],
#        ['R7444', 13, 0, ..., 'Dentro de la red', 'Usted no paga', 6],
#        ['R7444', 13, 0, ..., 'Fuera de la red', '40%', 19]], dtype=object)

# %%
df2 = df.head(2)
#crear nuevo dataframe

# %%
df2.head()
#visualizar dataframe
# Out:
#   Contract_ID  Plan_ID  Segment_ID  Contract_Year Language_Name  \
# 0       H0001        1           0           2019       English
# 1       H0001        1           0           2019       Spanish
#
#                        Category_Name  Category_Sort Service_Name  Limit_Flag  \
# 0             Health plan deductible              1          NaN         NaN
# 1  Deducibles de los planes de salud              1          NaN         NaN
#
#    Authorization_Flag  Referral Flag  Service_Sort Network_Description  \
# 0                 NaN            NaN             0                 NaN
# 1                 NaN            NaN             0                 NaN
#
#   Cost_Share  Network_Sort
# 0       $185             5
# 1       $185             5
