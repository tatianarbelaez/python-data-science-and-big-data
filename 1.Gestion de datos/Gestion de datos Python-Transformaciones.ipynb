# %%
# -*- coding: utf-8 -*-
import pandas as pd
df_finance = pd.read_csv(r"C:\Users\user\Downloads\catalogo_cf.csv", encoding='iso-8859-1', nrows = 1000000)

# %%
df_finanzas.columns
# Out:
# Index(['Nombre de la serie ', 'Número secuencial', 'Alias de la serie',
#        'Nombre del archivo con los valores de la serie',
#        'Descripción de la serie', 'Tipo de variable', 'Código de unidades',
#        'Exponente', 'Número de decimales',
#        'Descripción de unidades y exponente', 'Frecuencia de la serie',
#        'Fecha de la primera observación', 'Fecha de la última observación',
#        'Número de observaciones', 'Título de la serie', 'Fuente', 'Notas'],
#       dtype='object')

# %%
df_finance['Decimales'] = round(df_finanzas['Número de decimales'] / 10)
#Creacion de nueva columna a partir de una existente

# %%
del(df_finance['Decimales'])
#borrar una columna

# %%
df_finance.drop(['Notas', 'Fuente'],axis=1)
#Borrar varias columnas, axis 1 es que debe buscar los nombres en columnas --> solo es visualizacion no cambia el dataframe en la memoria
# Out:
#                   Nombre de la serie   Número secuencial Alias de la serie  \
# 0      DSPC102016CP30000_ES1_VCNTRA.T            3777714          CF_1_1.1
# 1            DSPC102016CP30000_ES14.T            3777708          CF_1_1.2
# 2            DSPC102016CP30000_ES15.T            3777711          CF_1_1.3
# 3     DSPC102016CP30000_ES13_VCNTRA.T            3777707          CF_1_1.4
# 4      DSPC102016CP51000_ES1_VCNTRA.T            3777761          CF_1_1.5
# ...                               ...                ...               ...
# 3701                    DMZ10F120B0.Q            2209065        CF_2_9B.27
# 3702                    DMZ10F500B0.Q            2210757        CF_2_9B.28
# 3703                    DMZ10F530B0.Q            2211725        CF_2_9B.29
# 3704                    DMZ10F300B0.Q            2209505        CF_2_9B.30
# 3705                    DMZ10F310B0.Q            2209810        CF_2_9B.31
#
#      Nombre del archivo con los valores de la serie  \
# ...

# %%
df_finance = df_finance.drop(['Notas', 'Fuente'],axis=1)
#Con esto, si borramos las columnas del dataframe en memoria
df_finance.drop(['Notas', 'Fuente'],axis=1, inplace=True)
#esta linea hace lo mismo de reemplazar el dataframe con el cambio

# %%
df_finance.drop(0)
df_finance.drop(range(13,28))
#Eliminan filas pero solo en visualizacion
# Out:
#                   Nombre de la serie   Número secuencial Alias de la serie  \
# 0      DSPC102016CP30000_ES1_VCNTRA.T            3777714          CF_1_1.1
# 1            DSPC102016CP30000_ES14.T            3777708          CF_1_1.2
# 2            DSPC102016CP30000_ES15.T            3777711          CF_1_1.3
# 3     DSPC102016CP30000_ES13_VCNTRA.T            3777707          CF_1_1.4
# 4      DSPC102016CP51000_ES1_VCNTRA.T            3777761          CF_1_1.5
# ...                               ...                ...               ...
# 3701                    DMZ10F120B0.Q            2209065        CF_2_9B.27
# 3702                    DMZ10F500B0.Q            2210757        CF_2_9B.28
# 3703                    DMZ10F530B0.Q            2211725        CF_2_9B.29
# 3704                    DMZ10F300B0.Q            2209505        CF_2_9B.30
# 3705                    DMZ10F310B0.Q            2209810        CF_2_9B.31
#
#      Nombre del archivo con los valores de la serie  \
# ...

# %%
D1 = df_finance[df_finance['Número de observaciones'] == 1]
E6 = df_finance[df_finance['Número de observaciones'] == 6]

# %%
D1_E6 = D1.append(E6)

# %%
D1_E6['Número de observaciones']
# Out:
# Series([], Name: Número de observaciones, dtype: int64)
